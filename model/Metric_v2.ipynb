# %%
import librosa
import numpy as np
import librosa.display
import matplotlib.pyplot as plt
import IPython.display as ipd
import pandas as pd
import os
import glob
from sklearn.decomposition import PCA

audios0 = []
first = True
sr = 44100


file_list = glob.glob('./AUDIO_DATA/0/*.wav')
for i,fname in enumerate(file_list):
#         ext = os.path.splitext(fname)[-2]
#         if ext[-1] == 'F':
    audio,_ = librosa.load(fname, sr=None, mono=False)
    if i%100==0:
        print(i)
#     display(ipd.Audio(audio, rate=sr))
    if first :
        audios0 = audio
        first = False
    else:
        audios0 = np.vstack((audios0, audio))
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800

# %%
      
audios1 = []
first = True
sr = 44100

file_list = glob.glob('./AUDIO_DATA/1/*.wav')
for i,fname in enumerate(file_list):
#         ext = os.path.splitext(fname)[-2]
#         if ext[-1] == 'F':
    audio,_ = librosa.load(fname, sr=None, mono=False)
    if i%100==0:
        print(i)
#     display(ipd.Audio(audio, rate=sr))
    if first :
        audios1 = audio
        first = False
    else:
        audios1 = np.vstack((audios1, audio))
        
audios2 = []
first = True
sr = 44100


file_list = glob.glob('./AUDIO_DATA/2/*.wav')
for i,fname in enumerate(file_list):
#         ext = os.path.splitext(fname)[-2]
#         if ext[-1] == 'F':
    audio,_ = librosa.load(fname, sr=None, mono=False)
    if i%100==0:
        print(i)
#     display(ipd.Audio(audio, rate=sr))
    if first :
        audios2 = audio
        first = False
    else:
        audios2 = np.vstack((audios2, audio))
        
        
audios3 = []
first = True
sr = 44100


file_list = glob.glob('./AUDIO_DATA/3/*.wav')
for i,fname in enumerate(file_list):
#         ext = os.path.splitext(fname)[-2]
#         if ext[-1] == 'F':
    audio,_ = librosa.load(fname, sr=None, mono=False)
    if i%100==0:
        print(i)
#     display(ipd.Audio(audio, rate=sr))
    if first :
        audios3 = audio
        first = False
    else:
        audios3 = np.vstack((audios3, audio))
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800

# %%
audios_all = np.vstack((audios0, audios1))
audios_all = np.vstack((audios_all, audios2))
audios_all = np.vstack((audios_all, audios3))

# %%
audios = audios0

step = int(sr*0.4/6)

stds = np.zeros((3,int(len(audios)//2)))
for j,J in enumerate([(0,1),(1,3),(3,6)]):
    for i in range(int(len(audios)//2)):
        audio = audios[2*i:2*(i+1),J[0]*step:J[1]*step]
        theta = np.pi/4
        trans = np.array([[np.cos(theta) ,-np.sin(theta)],[np.sin(theta), np.cos(theta)]])
        stds[j,i] = np.std(np.dot(trans,audio)[0])

plt.figure(figsize=(15,15))
plt.subplot(311)
plt.hist(stds[0],bins=20)
plt.title('front')
plt.xlim(0,0.5)
plt.ylim(0,450)
plt.subplot(312)
plt.title('mid')
plt.hist(stds[1],bins=20)
plt.xlim(0,0.5)
plt.ylim(0,450)
plt.subplot(313)
plt.title('end')
plt.hist(stds[2],bins=20)
plt.xlim(0,0.5)
plt.ylim(0,450)
plt.show()
audios = audios1

step = int(sr*0.4/6)

stds = np.zeros((3,int(len(audios)//2)))
for j,J in enumerate([(0,1),(1,3),(3,6)]):
    for i in range(int(len(audios)//2)):
        audio = audios[2*i:2*(i+1),J[0]*step:J[1]*step]
        theta = np.pi/4
        trans = np.array([[np.cos(theta) ,-np.sin(theta)],[np.sin(theta), np.cos(theta)]])
        stds[j,i] = np.std(np.dot(trans,audio)[0])

plt.figure(figsize=(15,15))
plt.subplot(311)
plt.hist(stds[0],bins=20)
plt.title('front')
plt.xlim(0,0.5)
plt.ylim(0,450)
plt.subplot(312)
plt.title('mid')
plt.hist(stds[1],bins=20)
plt.xlim(0,0.5)
plt.ylim(0,450)
plt.subplot(313)
plt.title('end')
plt.hist(stds[2],bins=20)
plt.xlim(0,0.5)
plt.ylim(0,450)
plt.show()

audios = audios2

step = int(sr*0.4/6)

stds = np.zeros((3,int(len(audios)//2)))
for j,J in enumerate([(0,1),(1,3),(3,6)]):
    for i in range(int(len(audios)//2)):
        audio = audios[2*i:2*(i+1),J[0]*step:J[1]*step]
        theta = np.pi/4
        trans = np.array([[np.cos(theta) ,-np.sin(theta)],[np.sin(theta), np.cos(theta)]])
        stds[j,i] = np.std(np.dot(trans,audio)[0])
plt.figure(figsize=(15,15))
plt.subplot(311)
plt.hist(stds[0],bins=20)
plt.title('front')
plt.xlim(0,0.5)
plt.ylim(0,450)
plt.subplot(312)
plt.title('mid')
plt.hist(stds[1],bins=20)
plt.xlim(0,0.5)
plt.ylim(0,450)
plt.subplot(313)
plt.title('end')
plt.hist(stds[2],bins=20)
plt.xlim(0,0.5)
plt.ylim(0,450)
plt.show()

audios = audios3

step = int(sr*0.4/6)

stds = np.zeros((3,int(len(audios)//2)))
for j,J in enumerate([(0,1),(1,3),(3,6)]):
    for i in range(int(len(audios)//2)):
        audio = audios[2*i:2*(i+1),J[0]*step:J[1]*step]
        theta = np.pi/4
        trans = np.array([[np.cos(theta) ,-np.sin(theta)],[np.sin(theta), np.cos(theta)]])
        stds[j,i] = np.std(np.dot(trans,audio)[0])

plt.figure(figsize=(15,15))
plt.subplot(311)
plt.hist(stds[0],bins=20)
plt.title('front')
plt.xlim(0,0.5)
plt.ylim(0,450)
plt.subplot(312)
plt.title('mid')
plt.hist(stds[1],bins=20)
plt.xlim(0,0.5)
plt.ylim(0,450)
plt.subplot(313)
plt.title('end')
plt.hist(stds[2],bins=20)
plt.xlim(0,0.5)
plt.ylim(0,450)
plt.show()

# %%
audios = audios_all

step = int(sr*0.4/6)

stds = np.zeros((3,int(len(audios)//2)))
for j,J in enumerate([(0,1),(1,3),(3,6)]):
    for i in range(int(len(audios)//2)):
        audio = audios[2*i:2*(i+1),J[0]*step:J[1]*step]
        theta = np.pi/4
        trans = np.array([[np.cos(theta) ,-np.sin(theta)],[np.sin(theta), np.cos(theta)]])
        stds[j,i] = np.std(np.dot(trans,audio)[0])

plt.figure(figsize=(15,15))
plt.subplot(311)
plt.hist(stds[0],bins=20)
plt.title('front')
plt.xlim(0,0.5)
plt.subplot(312)
plt.title('mid')
plt.hist(stds[1],bins=20)
plt.xlim(0,0.5)
plt.subplot(313)
plt.title('end')
plt.hist(stds[2],bins=20)
plt.xlim(0,0.5)
plt.show()

# %%
np.percentile(stds[:2,:].reshape(-1),60)
# Out:
# 0.14795353426771884

# %%
labels = (stds>0.125).T
labels
labels_s=[]
bins=np.zeros(8)
for i in range(len(labels)):
    if labels[i,0]==True:
        if labels[i,1]==True:
            if labels[i,2]==True:
                bins[0] = bins[0]+1
            else:
                bins[1] = bins[1]+1
        else:
            if labels[i,2]==True:
                bins[2] = bins[2]+1
            else:
                bins[3] = bins[3]+1
    else:
        if labels[i,1]==True:
            if labels[i,2]==True:
                bins[4] = bins[4]+1
            else:
                bins[5] = bins[5]+1
        else:
            if labels[i,2]==True:
                bins[6] = bins[6]+1
            else:
                bins[7] = bins[7]+1

# %%
index = [["WWW","WWN","WNW","WNN","NWW","NWN","NNW","NNN",]]

# %%
plt.figure(figsize=(15,7))
plt.bar(index,bins)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2368                 try:
# -> 2369                     left = x - width / 2
#    2370                 except TypeError as e:
#
# UFuncTypeError: ufunc 'subtract' did not contain a loop with signature matching types (dtype('<U32'), dtype('<U32')) -> dtype('<U32')
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-908054f9128f> in <module>
#       1 plt.figure(figsize=(15,7))
# ----> 2 plt.bar(index,bins)
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
# ...

# %%
plt.figure(figsize=(18,10))
plt.hist(labels_t)
# Out:
# (array([3082., 2512., 1214.,    0., 2464., 1210.,    0.,  774.,  242.,
#           22.]),
#  array([0. , 0.7, 1.4, 2.1, 2.8, 3.5, 4.2, 4.9, 5.6, 6.3, 7. ]),
#  <a list of 10 Patch objects>)

# %%
audios = []
first = True
sr = 44100


file_list = ['./AUDIO_DATA/0/00000004_D#.wav','./AUDIO_DATA/0/00000020_E.wav','./AUDIO_DATA/0/00110439_D#.wav','./AUDIO_DATA/2/02010277_E.wav','./AUDIO_DATA/0/00000026_E.wav']
for i,fname in enumerate(file_list):
#         ext = os.path.splitext(fname)[-2]
#         if ext[-1] == 'F':
    audio,_ = librosa.load(fname, sr=None, mono=False)
    if i%100==0:
        print(i)
#     display(ipd.Audio(audio, rate=sr))
    if first :
        audios = audio
        first = False
    else:
        audios = np.vstack((audios, audio))
# Out:
# 0

# %%
def LRMS_lissajous(i):
    L = audios[2*i]
    R = audios[2*i+1]
    display(ipd.Audio(audios[2*i:2*(i+1)],rate = 44100))

    plt.figure(figsize=(10,10))
#     plt.subplot(121)
    plt.plot([-1,1],[-1,1],'k',linewidth=1)
    plt.scatter(L,R, s=1)
    plt.plot([-1,1],[1,-1],'k',linewidth=0.1)
    plt.ylim([-1,1])
    plt.xlim([-1,1])
    plt.legend(['mono'],loc='upper left')
    plt.xlabel('L')
    plt.ylabel('R')

    plt.show()

# %%
for i in range(len(file_list)):
    LRMS_lissajous(i)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
# ...

# %%
step = int(sr*0.4/6)

stds = np.zeros((3,len(file_list)))
for j,J in enumerate([(0,1),(1,3),(3,6)]):
    for i in range(len(file_list)):
        audio = audios[2*i:2*(i+1),J[0]*step:J[1]*step]
        theta = np.pi/4
        trans = np.array([[np.cos(theta) ,-np.sin(theta)],[np.sin(theta), np.cos(theta)]])
        stds[j,i] = np.std(np.dot(trans,audio)[0])

plt.figure(figsize=(15,8))
for i in range(len(file_list)):        
    plt.plot([0.5,2,4.5],stds[:,i]) 
plt.xlim([0,6])
plt.ylim([0,0.15])
plt.legend(range(len(file_list)))
plt.show()

# %%
step = int(sr*0.4/6)

stds = np.zeros((3,len(file_list)))
for j,J in enumerate([(0,1),(1,3),(3,6)]):
    for i in range(len(file_list)):
        audio = audios[2*i:2*(i+1),J[0]*step:J[1]*step]
        theta = np.pi/4
        trans = np.array([[np.cos(theta) ,-np.sin(theta)],[np.sin(theta), np.cos(theta)]])
        stds[j,i] = np.std(np.dot(trans,audio)[0])

plt.figure(figsize=(15,15))
plt.subplot(311)
plt.hist(stds[0],bins=20)
plt.title('front')
plt.xlim(0,0.5)
plt.subplot(312)
plt.title('mid')
plt.hist(stds[1],bins=20)
plt.xlim(0,0.5)
plt.subplot(313)
plt.title('end')
plt.hist(stds[2],bins=20)
plt.xlim(0,0.5)
plt.show()

# %%
step = int(sr*0.4/8)

stds = np.zeros((3,len(file_list)))
for j,J in enumerate([(0,1),(1,4),(4,8)]):
    for i in range(len(file_list)):
        audio = audios[2*i:2*(i+1),J[0]*step:J[1]*step]
        theta = np.pi/4
        trans = np.array([[np.cos(theta) ,-np.sin(theta)],[np.sin(theta), np.cos(theta)]])
        stds[j,i] = np.std(np.dot(trans,audio)[0])

plt.figure(figsize=(15,15))
plt.subplot(311)
plt.hist(stds[0],bins=20)
plt.title('front')
plt.xlim(0,0.5)
plt.subplot(312)
plt.title('mid')
plt.hist(stds[1],bins=20)
plt.xlim(0,0.5)
plt.subplot(313)
plt.title('end')
plt.hist(stds[2],bins=20)
plt.xlim(0,0.5)
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.subplot(311)
plt.hist(stds[0])
plt.xlim(0,0.2)
plt.subplot(312)
plt.hist(stds[1])
plt.xlim(0,0.2)
plt.subplot(313)
plt.hist(stds[2])
plt.xlim(0,0.2)
plt.show()
