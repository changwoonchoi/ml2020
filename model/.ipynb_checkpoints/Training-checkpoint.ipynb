# %%
import os
import random
import warnings
from PIL import Image
from PGGAN import *
import torch.optim as optim
import torch.backends.cudnn as cudnn

import torch.utils.data as udata
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"

folder ='../train_making'
BATCH_SIZE= 4
DEVICE = torch.device("cuda")
G_LR = 2e-4
D_LR = 4e-4
ADAM_BETA = (0.0, 0.99)
ADAM_EPS = 1e-8
LAMBDA_FOR_WGANGP = 1
CRITIC_FOR_WGANGP = 1

TOTAL_DATA_SIZE=25904 #Gsynth dataset size

        
class PGGAN(object):
    def __init__(self,
                 latent_size,           # Dimensionality of the latent vectors.
                 criterion_type="GAN",  # ["GAN", "WGAN-GP"]
                 rgb_channel=4,         # Output channel size, for rgb always 3
                 fmap_base=2 ** 11,     # Overall multiplier for the number of feature maps.
                 fmap_decay=1.0,        # log2 feature map reduction when doubling the resolution.
                 fmap_max=2 ** 6,       # Maximum number of feature maps in any layer.
                 is_tanh=True,
                 is_sigmoid=True
                 ):
        self.latent_size_ = latent_size
        self.rgb_channel_ = rgb_channel
        self.fmap_base_ = fmap_base
        self.fmap_decay_ = fmap_decay
        self.fmap_max_ = fmap_max
        
        # self.stable_and_fadein_step = [6, 6, 6, 6, 6, 6, 30]
        self.stable_and_fadein_step = [1,1,1,1,1,1,1]


        self.criterion_type_ = criterion_type
        self.is_tanh_ = is_tanh
        self.is_sigmoid_ = False if self.criterion_type_ in ["WGAN-GP"] else is_sigmoid

        self.gradient_weight_real_ = torch.FloatTensor([-1]).cuda()
        self.gradient_weight_fake_ = torch.FloatTensor([1]).cuda()
    
        self._init_network()
        self.avg_layer = torch.nn.AvgPool2d((2,2),stride=(2,2))
    
        
    def range_normalizer(self, train_loader, magnitude_margin, IF_margin):
        min_spec = 10000
        max_spec = -10000
        min_IF = 10000
        max_IF = -10000

        for batch_idx, (pitch_label, mel_spec, mel_IF) in enumerate(train_loader): 
            
            mel_spec_L = torch.transpose(mel_spec,0,1)[0]
            mel_spec_R = torch.transpose(mel_spec,0,1)[1]
            mel_IF_L = torch.transpose(mel_IF,0,1)[0]
            mel_IF_R = torch.transpose(mel_IF,0,1)[1]
            
            spec_L = mel_spec_L
            IF_L = mel_IF_L
            spec_R = mel_spec_R
            IF_R = mel_IF_R

            if spec_L.min() < min_spec: min_spec=spec_L.min()
            if spec_R.min() < min_spec: min_spec=spec_R.min()
            if spec_L.max() > max_spec: max_spec=spec_L.max()
            if spec_R.max() > max_spec: max_spec=spec_R.max()

            if IF_L.min() < min_IF: min_IF=IF_L.min()
            if IF_R.min() < min_IF: min_IF=IF_R.min()
            if IF_L.max() > max_IF: max_IF=IF_L.max()
            if IF_R.max() > max_IF: max_IF=IF_R.max()

        self.s_a = magnitude_margin * (2.0 / (max_spec - min_spec))
        self.s_b = magnitude_margin * (-2.0 * min_spec / (max_spec - min_spec) - 1.0)
        
        self.p_a = IF_margin * (2.0 / (max_IF - min_IF))
        self.p_b = IF_margin * (-2.0 * min_IF / (max_IF - min_IF) - 1.0)

        
    def normalize(self, feature_map):
        a = np.asarray([self.s_a, self.p_a, self.s_a, self.p_a])[None, :, None, None]
        b = np.asarray([self.s_b, self.p_b, self.s_b, self.p_b])[None, :, None, None]
        a = torch.FloatTensor(a).cuda()
        b = torch.FloatTensor(b).cuda()
        feature_map = feature_map *a + b
        return feature_map

    
    def train(self):
        
        self._init_optimizer()
        self._init_criterion()
        
        # Declare Model status
        net_level = 0
        net_status = "stable"
        net_alpha = 1.0
        
        for cur_level in range(7):
            self.stable_steps = self.stable_and_fadein_step[cur_level]
            self.fadein_steps = self.stable_and_fadein_step[cur_level] 

            if cur_level==6:
                self.stable_steps = 100
#                 for step in range(self.stable_steps):
#                     self._train(cur_level, net_status, net_alpha, step)
                
            if cur_level ==0:
                net_status == "stable"
                for step in range(self.stable_steps):
                    self._train(cur_level, net_status, net_alpha, step)
            else:
                net_status = "fadein"
                
                for step in range(self.fadein_steps):
                    self._train(cur_level, "fadein", net_alpha, step)
                    
                for step in range(self.stable_steps*2):
                    net_alpha = 1.0
                    self._train(cur_level, "stable", net_alpha, step)
                    if cur_level ==6:
                        torch.save(self.g_net.state_dict(), folder + '/Gnet_%dx%d_step%d.pth' % (2 ** (cur_level + 1), 2 ** (cur_level + 4), step))
                        torch.save(self.d_net.state_dict(), folder + '/Dnet_%dx%d_step%d.pth' % (2 ** (cur_level + 1), 2 ** (cur_level + 4), step))
            torch.save(self.g_net.state_dict(), folder + '/Gnet_%dx%d.pth' % (2 ** (cur_level + 1), 2 ** (cur_level + 4)))
            torch.save(self.d_net.state_dict(), folder + '/Dnet_%dx%d.pth' % (2 ** (cur_level + 1), 2 ** (cur_level + 4)))


    def _train(self, net_level, net_status, net_alpha, cur_step):
        current_level_res = 2 ** 5
        batch_idx = 0
        batch_cnt = 0
        while batch_idx < int(TOTAL_DATA_SIZE/BATCH_SIZE):
            if batch_idx == (24000/BATCH_SIZE):
                train_loader = udata.DataLoader(udata.TensorDataset(
                                    torch.Tensor(np.load('../np_array_LR/'+'pitch_list_'+ str(TOTAL_DATA_SIZE) + '.npy')),
                                    torch.Tensor(np.load('../np_array_LR/'+'mel_spec_list_' + str(TOTAL_DATA_SIZE) + '.npy')),
                                    torch.Tensor(np.load('../np_array_LR/'+'mel_IF_list_' + str(TOTAL_DATA_SIZE) + '.npy'))
                                           ), batch_size=BATCH_SIZE, shuffle=True)
                print("load {}th file".format(TOTAL_DATA_SIZE))
                self.range_normalizer(train_loader, magnitude_margin=0.8, IF_margin=1.0)
                
            elif batch_idx % (4000/BATCH_SIZE) == 0:
                train_loader = udata.DataLoader(udata.TensorDataset(
                                    torch.Tensor(np.load('../np_array_LR/'+'pitch_list_'+ str(batch_idx*BATCH_SIZE+4000) + '.npy')),
                                    torch.Tensor(np.load('../np_array_LR/'+'mel_spec_list_' + str(batch_idx*BATCH_SIZE+4000) + '.npy')),
                                    torch.Tensor(np.load('../np_array_LR/'+'mel_IF_list_' + str(batch_idx*BATCH_SIZE+4000) + '.npy'))
                                           ), batch_size=BATCH_SIZE, shuffle=True)
                print("load {}th file".format((batch_idx*BATCH_SIZE+4000)))
                self.range_normalizer(train_loader, magnitude_margin=0.8, IF_margin=1.0)
                       
            for batch_idx2, (pitch_label, mel_spec, mel_IF) in enumerate(train_loader):        

                # train mel spec IF
                mel_spec_L = torch.transpose(mel_spec,0,1)[0]
                mel_spec_R = torch.transpose(mel_spec,0,1)[1]
                mel_IF_L = torch.transpose(mel_IF,0,1)[0]
                mel_IF_R = torch.transpose(mel_IF,0,1)[1]
                
                spec_L = mel_spec_L
                IF_L = mel_IF_L
                spec_R = mel_spec_R
                IF_R = mel_IF_R

                stack_real_image = torch.stack((spec_L,IF_L,spec_R,IF_R),dim=1).cuda()
                
                stack_real_image = torch.transpose(stack_real_image,2,3)

                little_batch_size = spec_L.size()[0]

                stack_real_image = stack_real_image.cuda()

                if net_status =='stable':
                    net_alpha = 1.0
                elif net_status =='fadein':

                    if little_batch_size==BATCH_SIZE:
                        net_alpha = 1.0 - (cur_step * TOTAL_DATA_SIZE + batch_idx * little_batch_size) / (self.fadein_steps * TOTAL_DATA_SIZE)
                    else:
                        net_alpha = 1.0 - (cur_step * TOTAL_DATA_SIZE + batch_idx*(BATCH_SIZE) + little_batch_size) / (self.fadein_steps * TOTAL_DATA_SIZE)

                if net_alpha< 0.0:
                    print("Alpha too small <0")
                    return 

                # change net status 
                self.g_net.net_config = [net_level, net_status, net_alpha]
                self.d_net.net_config = [net_level, net_status, net_alpha]

                """ Make Fake Condition Vector """
                pitch_label = pitch_label.cuda()

                
                fake_pitch_label = torch.LongTensor(little_batch_size, 1).random_() % 8
                fake_one_hot_pitch_condition_vector = torch.zeros(little_batch_size, 8).scatter_(1, fake_pitch_label, 1).unsqueeze(2).unsqueeze(3).cuda()
                fake_pitch_label = fake_pitch_label.cuda().squeeze()

                # batch = 1 일 때 문제 생기던데 squeeze 되면서 dimension 다 날아가는 것 처럼 보임

                """ generate random vector """
                fake_seed = torch.randn(little_batch_size, self.latent_size_, 1, 1).cuda()
                fake_seed_and_pitch_condition = torch.cat((fake_seed, fake_one_hot_pitch_condition_vector), dim=1)
               
                fake_generated_sample = self.g_net(fake_seed_and_pitch_condition)
                
                stack_real_image = self.normalize(stack_real_image)
                
                pitch_real, d_real = self.d_net(stack_real_image)
                pitch_fake, d_fake  = self.d_net(fake_generated_sample.detach())


                # WGAN-GP
                """ update d_net """
                # real:-1 fake:1
                for p in self.d_net.parameters():
                    p.requires_grad = True 
                self.d_net.zero_grad()


                # Train D with Real 
                mean_real = d_real.mean() # wgan loss 
                # mean_real = nn.ReLU()(1.0 - d_real).mean() #hinge loss


                # Train D with Fake 
                mean_fake = d_fake.mean() # wgan loss
                # mean_fake = nn.ReLU()(1.0 + d_fake).mean() # hinge loss


                # Train D with GP 
                gradient_penalty = 10 * self._gradient_penalty(stack_real_image.data, fake_generated_sample.data, little_batch_size, current_level_res)


                # Train D with classifier Loss
                
                pitch_label = pitch_label.long()

                real_pitch_loss = self.NLL_loss(pitch_real, pitch_label)
                fake_pitch_loss = self.NLL_loss(pitch_fake, fake_pitch_label)
                p_loss = 10 *(real_pitch_loss)

                
                # D_loss = mean_fake + mean_real + gradient_penalty + p_loss # hinge
                D_loss = mean_fake - mean_real + gradient_penalty + p_loss # wgan-gp
                Wasserstein_D = mean_real - mean_fake

                D_loss.backward()
                self.d_optim.step()

                if batch_idx % 3 == 0: # avoid Mode Collpase which caused by strong Generator
                    """ update g_net """
                    for p in self.d_net.parameters():
                        p.requires_grad = False  # to avoid computation
                    self.g_net.zero_grad()
                    
                    pitch_fake, d_fake = self.d_net(fake_generated_sample)
                    mean_fake = d_fake.mean()

                    fake_pitch_loss = self.NLL_loss(pitch_fake, fake_pitch_label)
                    timed_fake_pitch_loss = 10 *fake_pitch_loss
                    G_loss = -mean_fake + timed_fake_pitch_loss
                    G_loss.backward()

                    
                self.g_optim.step()
                if batch_idx %2000 ==0:
                    self.generate_picture(fake_generated_sample[0,:,:,:], current_level_res, cur_step, batch_idx, net_status)
                if batch_idx %200==0:
                    print("Resolution:{}x{}, Status:{}, Cur_step:{}, Batch_id:{}, D_loss:{}, W_D:{}, M_fake:{}, M_Real:{}, GP:{}, Real_P_Loss:{}, Fake_P_Loss:{}, G_loss:{}, Net_alpha:{}".format(\
                            current_level_res, current_level_res*(2**5), net_status, cur_step, batch_idx, D_loss, Wasserstein_D, mean_fake, mean_real, real_pitch_loss, fake_pitch_loss, gradient_penalty, G_loss, net_alpha))

                batch_idx = batch_cnt*int(4000/BATCH_SIZE) + batch_idx2 + 1
                if batch_idx2 == int(4000/BATCH_SIZE) - 1:
                    batch_cnt = batch_cnt + 1
                
        print("self.fadein_steps",self.fadein_steps* TOTAL_DATA_SIZE,\
              "cur_step",(cur_step * TOTAL_DATA_SIZE + batch_idx * little_batch_size),\
              "net_alpha",net_alpha
              )
        
        
    def generate_picture(self, spec, resolution, step, batch_idx, status):
#         spec = spec.data.cpu().numpy()
#         stack_spec = np.hstack((spec[0],spec[1],spec[2],spec[3]))
#         flip_stack = np.flipud(stack_spec)
#         fig = plt.figure(figsize=(20,7))
#         plt.imshow(stack_spec,aspect='auto')

        spec = spec.data.cpu().numpy()
        stack_spec = np.hstack((spec[0],spec[2]))
        flip_stack = np.flipud(stack_spec)
        fig = plt.figure(figsize=(20,7))
        plt.imshow(stack_spec,aspect='auto')    
        
        plt.savefig( folder + "/{}_{}_{}_{}_{}_sample.png".format(resolution, resolution*(2**5), status, step, batch_idx ))
    

    def _init_criterion(self):
        
        self.criterion = self._gradient_penalty
        self.NLL_loss = nn.NLLLoss()


    def _init_network(self):
        # Init Generator and Discriminator
        print("Create Network")
        self.g_net = Generator(256, self.latent_size_, self.rgb_channel_,
                                is_tanh=self.is_tanh_, channel_list=[256,256,256,256,256,128,64,32])
        self.d_net = Discriminator(256, self.rgb_channel_,
                                   is_sigmoid=self.is_sigmoid_, channel_list=[256,256,256,256,128,64,32,32])
        # if TO_GPU:
        self.g_net.cuda(0)
        self.d_net.cuda(0)
        print(self.g_net)
        print(self.d_net)
        
        
    def _init_optimizer(self):
        self.g_optim = optim.Adam(self.g_net.parameters(), lr=G_LR, betas=ADAM_BETA, eps=ADAM_EPS)
        self.d_optim = optim.Adam(self.d_net.parameters(), lr=D_LR, betas=ADAM_BETA, eps=ADAM_EPS)
        
    def _gradient_penalty(self, real_data, fake_data, batch_size, res):
        """
        This algorithm was mentioned on the Page4 of paper
        'Improved Training of Wasserstein GANs'
        This implementation was from 'https://github.com/caogang/wgan-gp'
        """
        
        epsilon = torch.rand(batch_size, 1)
        
        epsilon = epsilon.expand(batch_size, int(real_data.nelement() / batch_size)).contiguous().view(batch_size, 4, res, res*(2**5))
        epsilon = epsilon.cuda()
        median_x = epsilon * real_data + ((1 - epsilon) * fake_data)

        # if TO_GPU:
        median_x = median_x.cuda()
        median_data = torch.autograd.Variable(median_x, requires_grad=True)

        _, d_median_data = self.d_net(median_data)

        gradients = torch.autograd.grad(outputs=d_median_data, inputs=median_data,
                                        grad_outputs=torch.ones(d_median_data.size()).cuda(),
                                        create_graph=True, retain_graph=True, only_inputs=True)[0]
        gradients = gradients.view(gradients.size(0), -1)

        gradient_penalty = ((gradients.norm(2, dim=1) - 1) ** 2).mean() * LAMBDA_FOR_WGANGP
        return gradient_penalty




def main():    
    p = PGGAN(256, criterion_type="WGAN-GP")
    p.train()   


if __name__ == "__main__":
    main()
# Out:
# Create Network
# Cursor 0 256 256
# Cursor 1 256 256
# Cursor 2 256 256
# Cursor 3 256 256
# Cursor 4 256 128
# Cursor 5 128 64
# Cursor 6 64 32
# Cursor 7 32 32
# Cursor 6 32 64
# Cursor 5 64 128
# Cursor 4 128 256
# Cursor 3 256 256
# Cursor 2 256 256
# Cursor 1 256 256
# Generator(
#   (lod_layers_): ModuleList(
#     (0): Sequential(
#       (0): PixelWiseNormLayer()
#       (1): Conv2d(264, 256, kernel_size=(2, 16), stride=(1, 1), padding=(1, 15), bias=False)
#       (2): EqualizedLearningRateLayer(
#         (layer_): Conv2d(264, 256, kernel_size=(2, 16), stride=(1, 1), padding=(1, 15), bias=False)
#       )
#       (3): LeakyReLU(negative_slope=0.2)
#       (4): PixelWiseNormLayer()
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (6): EqualizedLearningRateLayer(
#         (layer_): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (7): LeakyReLU(negative_slope=0.2)
#       (8): PixelWiseNormLayer()
#     )
#     (1): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): EqualizedLearningRateLayer(
#         (layer_): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (3): LeakyReLU(negative_slope=0.2)
#       (4): PixelWiseNormLayer()
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (6): EqualizedLearningRateLayer(
#         (layer_): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (7): LeakyReLU(negative_slope=0.2)
#       (8): PixelWiseNormLayer()
#     )
#     (2): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): EqualizedLearningRateLayer(
#         (layer_): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (3): LeakyReLU(negative_slope=0.2)
#       (4): PixelWiseNormLayer()
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (6): EqualizedLearningRateLayer(
#         (layer_): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (7): LeakyReLU(negative_slope=0.2)
#       (8): PixelWiseNormLayer()
#     )
#     (3): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): EqualizedLearningRateLayer(
#         (layer_): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (3): LeakyReLU(negative_slope=0.2)
#       (4): PixelWiseNormLayer()
#       (5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (6): EqualizedLearningRateLayer(
#         (layer_): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (7): LeakyReLU(negative_slope=0.2)
#       (8): PixelWiseNormLayer()
#     )
#     (4): Sequential(
#       (0): Upsample(scale_factor=2.0, mode=nearest)
#       (1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): EqualizedLearningRateLayer(
#         (layer_): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (3): LeakyReLU(negative_slope=0.2)
#       (4): PixelWiseNormLayer()
#       (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (6): EqualizedLearningRateLayer(
#         (layer_): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (7): LeakyReLU(negative_slope=0.2)
#       (8): PixelWiseNormLayer()
#     )
#     (5): Sequential(
#       (0): Upsample(scale_factor=(1.0, 2.0), mode=nearest)
#       (1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): EqualizedLearningRateLayer(
#         (layer_): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (3): LeakyReLU(negative_slope=0.2)
#       (4): PixelWiseNormLayer()
#       (5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (6): EqualizedLearningRateLayer(
#         (layer_): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (7): LeakyReLU(negative_slope=0.2)
#       (8): PixelWiseNormLayer()
#     )
#     (6): Sequential(
#       (0): Upsample(scale_factor=(1.0, 2.0), mode=nearest)
#       (1): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): EqualizedLearningRateLayer(
#         (layer_): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (3): LeakyReLU(negative_slope=0.2)
#       (4): PixelWiseNormLayer()
#       (5): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (6): EqualizedLearningRateLayer(
#         (layer_): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (7): LeakyReLU(negative_slope=0.2)
#       (8): PixelWiseNormLayer()
#     )
#   )
#   (rgb_layers_): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(256, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): EqualizedLearningRateLayer(
#         (layer_): Conv2d(256, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (2): Tanh()
#     )
#     (1): Sequential(
#       (0): Conv2d(256, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): EqualizedLearningRateLayer(
#         (layer_): Conv2d(256, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (2): Tanh()
#     )
#     (2): Sequential(
#       (0): Conv2d(256, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): EqualizedLearningRateLayer(
#         (layer_): Conv2d(256, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (2): Tanh()
#     )
#     (3): Sequential(
#       (0): Conv2d(256, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): EqualizedLearningRateLayer(
#         (layer_): Conv2d(256, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (2): Tanh()
#     )
#     (4): Sequential(
#       (0): Conv2d(128, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): EqualizedLearningRateLayer(
#         (layer_): Conv2d(128, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (2): Tanh()
#     )
#     (5): Sequential(
#       (0): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): EqualizedLearningRateLayer(
#         (layer_): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (2): Tanh()
#     )
#     (6): Sequential(
#       (0): Conv2d(32, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): EqualizedLearningRateLayer(
#         (layer_): Conv2d(32, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (2): Tanh()
#     )
#   )
# )
# Discriminator(
#   (lod_layers_): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): EqualizedLearningRateLayer(
#         (layer_): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): EqualizedLearningRateLayer(
#         (layer_): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (5): LeakyReLU(negative_slope=0.2)
#       (6): AvgPool2d(kernel_size=(1, 2), stride=(1, 2), padding=0)
#     )
#     (1): Sequential(
#       (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): EqualizedLearningRateLayer(
#         (layer_): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): EqualizedLearningRateLayer(
#         (layer_): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (5): LeakyReLU(negative_slope=0.2)
#       (6): AvgPool2d(kernel_size=(1, 2), stride=(1, 2), padding=0)
#     )
#     (2): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): EqualizedLearningRateLayer(
#         (layer_): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): EqualizedLearningRateLayer(
#         (layer_): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (5): LeakyReLU(negative_slope=0.2)
#       (6): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (3): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): EqualizedLearningRateLayer(
#         (layer_): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): EqualizedLearningRateLayer(
#         (layer_): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (5): LeakyReLU(negative_slope=0.2)
#       (6): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (4): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): EqualizedLearningRateLayer(
#         (layer_): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): EqualizedLearningRateLayer(
#         (layer_): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (5): LeakyReLU(negative_slope=0.2)
#       (6): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (5): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): EqualizedLearningRateLayer(
#         (layer_): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): EqualizedLearningRateLayer(
#         (layer_): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (5): LeakyReLU(negative_slope=0.2)
#       (6): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (6): Sequential(
#       (0): MiniBatchAverageLayer()
#       (1): Conv2d(257, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (2): EqualizedLearningRateLayer(
#         (layer_): Conv2d(257, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (3): LeakyReLU(negative_slope=0.2)
#       (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (5): EqualizedLearningRateLayer(
#         (layer_): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (6): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (rgb_layers_): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(4, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): EqualizedLearningRateLayer(
#         (layer_): Conv2d(4, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (1): Sequential(
#       (0): Conv2d(4, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): EqualizedLearningRateLayer(
#         (layer_): Conv2d(4, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (2): Sequential(
#       (0): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): EqualizedLearningRateLayer(
#         (layer_): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (3): Sequential(
#       (0): Conv2d(4, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): EqualizedLearningRateLayer(
#         (layer_): Conv2d(4, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (4): Sequential(
#       (0): Conv2d(4, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): EqualizedLearningRateLayer(
#         (layer_): Conv2d(4, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (5): Sequential(
#       (0): Conv2d(4, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): EqualizedLearningRateLayer(
#         (layer_): Conv2d(4, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (6): Sequential(
#       (0): Conv2d(4, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): EqualizedLearningRateLayer(
#         (layer_): Conv2d(4, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#   )
#   (pitch_classifier): Linear(in_features=8192, out_features=8, bias=True)
#   (discriminator_classifier): Linear(in_features=8192, out_features=1, bias=True)
#   (Softmax): LogSoftmax()
# )
# load 4000th file
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:0, D_loss:15.201878547668457, W_D:-0.000494765117764473, M_fake:-0.01075664535164833, M_Real:-0.008510902523994446, GP:0.5202525854110718, Real_P_Loss:2.0817718505859375, Fake_P_Loss:9.998857498168945, G_loss:20.828475952148438, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:200, D_loss:-49.383934020996094, W_D:60.73843765258789, M_fake:3.136045217514038, M_Real:63.874481201171875, GP:0.8398502469062805, Real_P_Loss:2.9150524139404297, Fake_P_Loss:2.9560022354125977, G_loss:22.174053192138672, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:400, D_loss:15.849427223205566, W_D:-15.319633483886719, M_fake:73.4788818359375, M_Real:58.15924835205078, GP:-0.02887675166130066, Real_P_Loss:3.5320303440093994, Fake_P_Loss:0.8185625076293945, G_loss:-41.412166595458984, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:600, D_loss:-111.46643829345703, W_D:141.6308135986328, M_fake:52.86669158935547, M_Real:191.0150604248047, GP:0.017316356301307678, Real_P_Loss:4.86950159072876, Fake_P_Loss:29.991214752197266, G_loss:-4.1716766357421875, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:800, D_loss:-37.618873596191406, W_D:59.28500747680664, M_fake:3.567491054534912, M_Real:62.85249710083008, GP:1.022463083267212, Real_P_Loss:1.8379228115081787, Fake_P_Loss:11.441503524780273, G_loss:37.403160095214844, Net_alpha:1.0
# load 8000th file
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:1000, D_loss:-6.481000900268555, W_D:11.867805480957031, M_fake:34.50701141357422, M_Real:46.37481689453125, GP:0.2180202156305313, Real_P_Loss:2.3398642539978027, Fake_P_Loss:3.2066023349761963, G_loss:28.164268493652344, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:1200, D_loss:-93.76029968261719, W_D:119.70082092285156, M_fake:13.45831298828125, M_Real:138.7447967529297, GP:0.2758644223213196, Real_P_Loss:1.7696266174316406, Fake_P_Loss:23.181875228881836, G_loss:4.237953186035156, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:1400, D_loss:-279.72052001953125, W_D:301.12322998046875, M_fake:0.20829011499881744, M_Real:301.3315124511719, GP:1.6692053079605103, Real_P_Loss:2.0869483947753906, Fake_P_Loss:4.710658073425293, G_loss:19.019245147705078, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:1600, D_loss:-245.259521484375, W_D:259.7430419921875, M_fake:28.260326385498047, M_Real:288.00335693359375, GP:-5.466480255126953, Real_P_Loss:5.09243631362915, Fake_P_Loss:69.14833068847656, G_loss:25.07980728149414, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:1800, D_loss:-121.7511978149414, W_D:175.5408477783203, M_fake:2.999074697494507, M_Real:191.10995483398438, GP:0.4237070083618164, Real_P_Loss:3.594414234161377, Fake_P_Loss:49.552581787109375, G_loss:32.945068359375, Net_alpha:1.0
# load 12000th file
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:2000, D_loss:-39.42042541503906, W_D:49.525108337402344, M_fake:17.533761978149414, M_Real:67.05886840820312, GP:0.38205477595329285, Real_P_Loss:4.600091934204102, Fake_P_Loss:6.284135818481445, G_loss:28.831703186035156, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:2200, D_loss:-102.30142211914062, W_D:117.32890319824219, M_fake:35.74276351928711, M_Real:153.07167053222656, GP:0.5022221803665161, Real_P_Loss:5.685900688171387, Fake_P_Loss:10.005255699157715, G_loss:-10.786968231201172, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:2400, D_loss:-77.83895874023438, W_D:96.48896789550781, M_fake:20.09741973876953, M_Real:113.17938232421875, GP:0.38500550389289856, Real_P_Loss:3.6471357345581055, Fake_P_Loss:14.799959182739258, G_loss:16.373939514160156, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:2600, D_loss:-90.6219253540039, W_D:98.41925048828125, M_fake:-0.2567632496356964, M_Real:98.16249084472656, GP:0.04952619969844818, Real_P_Loss:3.347715139389038, Fake_P_Loss:7.302065849304199, G_loss:73.14981842041016, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:2800, D_loss:-83.39938354492188, W_D:139.83148193359375, M_fake:20.00771713256836, M_Real:159.83920288085938, GP:-0.047633275389671326, Real_P_Loss:5.408498287200928, Fake_P_Loss:56.90843200683594, G_loss:84.48783874511719, Net_alpha:1.0
# load 16000th file
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:3000, D_loss:-75.09514617919922, W_D:98.53742980957031, M_fake:27.255691528320312, M_Real:126.32571411132812, GP:0.5808818340301514, Real_P_Loss:6.495018005371094, Fake_P_Loss:17.633464813232422, G_loss:37.694488525390625, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:3200, D_loss:-35.857608795166016, W_D:49.32746124267578, M_fake:82.86800384521484, M_Real:132.19546508789062, GP:0.3001250624656677, Real_P_Loss:10.148252487182617, Fake_P_Loss:10.468602180480957, G_loss:-57.20529556274414, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:3400, D_loss:-118.23310852050781, W_D:161.3644256591797, M_fake:15.95826530456543, M_Real:177.32269287109375, GP:0.966029167175293, Real_P_Loss:2.1048192977905273, Fake_P_Loss:33.47102355957031, G_loss:4.700191497802734, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:3600, D_loss:-124.53749084472656, W_D:159.24867248535156, M_fake:56.620635986328125, M_Real:210.2331085205078, GP:0.3432208001613617, Real_P_Loss:7.4001617431640625, Fake_P_Loss:31.278972625732422, G_loss:17.3809814453125, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:3800, D_loss:-202.40093994140625, W_D:240.5841522216797, M_fake:12.146976470947266, M_Real:252.7311248779297, GP:-0.10835763812065125, Real_P_Loss:3.0461173057556152, Fake_P_Loss:39.266780853271484, G_loss:48.37390899658203, Net_alpha:1.0
# load 20000th file
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:4000, D_loss:-24.9588565826416, W_D:81.47113037109375, M_fake:25.233779907226562, M_Real:106.70491027832031, GP:0.20873309671878815, Real_P_Loss:5.336724281311035, Fake_P_Loss:54.42494201660156, G_loss:27.623090744018555, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:4200, D_loss:-234.17849731445312, W_D:312.26788330078125, M_fake:17.65757179260254, M_Real:328.0798645019531, GP:1.1244405508041382, Real_P_Loss:4.56746244430542, Fake_P_Loss:66.84498596191406, G_loss:28.017053604125977, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:4400, D_loss:-114.5265884399414, W_D:150.7894744873047, M_fake:19.4705810546875, M_Real:170.2600555419922, GP:0.04959942400455475, Real_P_Loss:6.551685810089111, Fake_P_Loss:35.76689147949219, G_loss:-2.2112998962402344, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:4600, D_loss:-264.86737060546875, W_D:370.283447265625, M_fake:44.13971710205078, M_Real:414.42315673828125, GP:-0.004403593949973583, Real_P_Loss:6.179368495941162, Fake_P_Loss:105.46011352539062, G_loss:-19.418397903442383, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:4800, D_loss:-112.8594970703125, W_D:144.0789337158203, M_fake:24.85611343383789, M_Real:168.1300048828125, GP:0.36686158180236816, Real_P_Loss:8.34199047088623, Fake_P_Loss:27.55082130432129, G_loss:58.56379318237305, Net_alpha:1.0
# load 24000th file
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:5000, D_loss:-99.27095794677734, W_D:116.61915588378906, M_fake:33.394012451171875, M_Real:150.01316833496094, GP:0.014395847916603088, Real_P_Loss:9.375286102294922, Fake_P_Loss:17.20423698425293, G_loss:26.3699951171875, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:5200, D_loss:-267.05999755859375, W_D:297.6202392578125, M_fake:34.92612838745117, M_Real:332.5463562011719, GP:-0.2230280637741089, Real_P_Loss:5.053494930267334, Fake_P_Loss:32.790531158447266, G_loss:18.358932495117188, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:5400, D_loss:-213.9515838623047, W_D:281.83514404296875, M_fake:122.62470245361328, M_Real:404.090576171875, GP:-0.41059455275535583, Real_P_Loss:8.536177635192871, Fake_P_Loss:71.989501953125, G_loss:-37.26292419433594, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:5600, D_loss:-255.0761260986328, W_D:296.22027587890625, M_fake:21.603145599365234, M_Real:317.82342529296875, GP:-0.19197174906730652, Real_P_Loss:5.477085113525391, Fake_P_Loss:43.063880920410156, G_loss:-22.016427993774414, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:5800, D_loss:-411.3493347167969, W_D:546.1130981445312, M_fake:29.539623260498047, M_Real:575.6527099609375, GP:0.08988910913467407, Real_P_Loss:3.921018123626709, Fake_P_Loss:133.8648681640625, G_loss:-8.746051788330078, Net_alpha:1.0
# load 25904th file
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:6000, D_loss:-246.74859619140625, W_D:293.60443115234375, M_fake:57.968788146972656, M_Real:347.9001770019531, GP:-0.9074043035507202, Real_P_Loss:2.226106643676758, Fake_P_Loss:55.92986297607422, G_loss:-35.70772171020508, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:6200, D_loss:-267.39898681640625, W_D:340.4545593261719, M_fake:41.099082946777344, M_Real:381.55364990234375, GP:0.911655068397522, Real_P_Loss:6.274237155914307, Fake_P_Loss:63.93903732299805, G_loss:-10.884044647216797, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:6400, D_loss:85.96138000488281, W_D:253.9541778564453, M_fake:87.31184387207031, M_Real:341.2660217285156, GP:29.795228958129883, Real_P_Loss:8.272757530212402, Fake_P_Loss:41.963253021240234, G_loss:-32.987266540527344, Net_alpha:1.0
# self.fadein_steps 25904 cur_step 25904 net_alpha 1.0
# load 4000th file
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:0, D_loss:86.8888168334961, W_D:-84.60140991210938, M_fake:72.16429901123047, M_Real:45.914981842041016, GP:0.22485311329364777, Real_P_Loss:15.480422019958496, Fake_P_Loss:0.03888004273176193, G_loss:82.6399154663086, Net_alpha:1.0
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:200, D_loss:-128.1410369873047, W_D:163.6340789794922, M_fake:62.96525573730469, M_Real:226.59933471679688, GP:-1.3744701147079468, Real_P_Loss:2.109290838241577, Fake_P_Loss:49.23773956298828, G_loss:-34.36391067504883, Net_alpha:0.9691167387276096
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:400, D_loss:-140.35487365722656, W_D:186.11917114257812, M_fake:35.05487823486328, M_Real:221.17404174804688, GP:0.39475879073143005, Real_P_Loss:14.180641174316406, Fake_P_Loss:41.81671905517578, G_loss:21.963035583496094, Net_alpha:0.9382334774552192
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:600, D_loss:-89.05647277832031, W_D:121.94775390625, M_fake:26.634620666503906, M_Real:143.1837158203125, GP:-0.04252365976572037, Real_P_Loss:8.837275505065918, Fake_P_Loss:33.31652069091797, G_loss:61.738136291503906, Net_alpha:0.9073502161828289
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:800, D_loss:-95.14879608154297, W_D:98.51166534423828, M_fake:29.755699157714844, M_Real:128.26736450195312, GP:-0.2514071464538574, Real_P_Loss:5.420803070068359, Fake_P_Loss:5.876941204071045, G_loss:-11.492923736572266, Net_alpha:0.8764669549104386
# load 8000th file
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:1000, D_loss:-50.69118118286133, W_D:59.74058532714844, M_fake:18.474769592285156, M_Real:78.2153549194336, GP:-0.19201624393463135, Real_P_Loss:10.631331443786621, Fake_P_Loss:10.96956729888916, G_loss:57.32075881958008, Net_alpha:0.8455836936380482
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:1200, D_loss:-100.15001678466797, W_D:109.42071533203125, M_fake:48.113037109375, M_Real:150.72463989257812, GP:-0.11438369750976562, Real_P_Loss:28.22445297241211, Fake_P_Loss:10.414538383483887, G_loss:234.13150024414062, Net_alpha:0.8147004323656578
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:1400, D_loss:-112.47016906738281, W_D:137.13217163085938, M_fake:39.120628356933594, M_Real:176.2528076171875, GP:0.2697766423225403, Real_P_Loss:1.8756887912750244, Fake_P_Loss:21.964235305786133, G_loss:9.540277481079102, Net_alpha:0.7838171710932674
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:1600, D_loss:-113.83838653564453, W_D:145.58847045898438, M_fake:45.42955017089844, M_Real:191.0180206298828, GP:-0.21140503883361816, Real_P_Loss:6.966154098510742, Fake_P_Loss:33.864131927490234, G_loss:54.00263977050781, Net_alpha:0.752933909820877
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:1800, D_loss:-218.77783203125, W_D:239.2296905517578, M_fake:25.730775833129883, M_Real:257.13702392578125, GP:-0.002220362424850464, Real_P_Loss:4.486285209655762, Fake_P_Loss:20.47405433654785, G_loss:19.132078170776367, Net_alpha:0.7220506485484868
# load 12000th file
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:2000, D_loss:16.348989486694336, W_D:6.9069671630859375, M_fake:68.29032897949219, M_Real:75.19729614257812, GP:-0.12943699955940247, Real_P_Loss:2.0372815132141113, Fake_P_Loss:24.55032730102539, G_loss:-57.34182357788086, Net_alpha:0.6911673872760964
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:2200, D_loss:-58.34410858154297, W_D:66.62008666992188, M_fake:-7.290021896362305, M_Real:59.3300666809082, GP:0.5137367248535156, Real_P_Loss:2.5116500854492188, Fake_P_Loss:3.1386117935180664, G_loss:106.16917419433594, Net_alpha:0.660284126003706
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:2400, D_loss:-70.55390167236328, W_D:85.50704956054688, M_fake:23.39728355407715, M_Real:104.26530456542969, GP:0.16961437463760376, Real_P_Loss:7.3852739334106445, Fake_P_Loss:13.257007598876953, G_loss:50.45545196533203, Net_alpha:0.6294008647313156
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:2600, D_loss:-75.72012329101562, W_D:99.6160888671875, M_fake:54.40460205078125, M_Real:154.02069091796875, GP:1.1535656452178955, Real_P_Loss:1.7410191297531128, Fake_P_Loss:12.360313415527344, G_loss:-39.61091995239258, Net_alpha:0.5985176034589252
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:2800, D_loss:-95.65493774414062, W_D:114.41302490234375, M_fake:87.86422729492188, M_Real:202.27725219726562, GP:0.001974448561668396, Real_P_Loss:2.2800917625427246, Fake_P_Loss:18.73834228515625, G_loss:-20.564441680908203, Net_alpha:0.5676343421865349
# load 16000th file
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:3000, D_loss:14.123259544372559, W_D:-9.677993774414062, M_fake:61.264949798583984, M_Real:72.88096618652344, GP:-0.27930766344070435, Real_P_Loss:19.231679916381836, Fake_P_Loss:7.238341331481934, G_loss:131.05184936523438, Net_alpha:0.5367510809141445
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:3200, D_loss:-17.471656799316406, W_D:24.438064575195312, M_fake:58.99298095703125, M_Real:83.43104553222656, GP:0.12649346888065338, Real_P_Loss:5.653511047363281, Fake_P_Loss:5.701472759246826, G_loss:12.737133026123047, Net_alpha:0.5058678196417541
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:3400, D_loss:-38.43656921386719, W_D:58.02774429321289, M_fake:41.6602897644043, M_Real:99.68803405761719, GP:0.6009505391120911, Real_P_Loss:3.4046759605407715, Fake_P_Loss:13.581668853759766, G_loss:1.22003173828125, Net_alpha:0.4749845583693638
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:3600, D_loss:-122.572998046875, W_D:136.42922973632812, M_fake:37.332427978515625, M_Real:160.46432495117188, GP:0.42198941111564636, Real_P_Loss:5.225523948669434, Fake_P_Loss:9.636338233947754, G_loss:14.922813415527344, Net_alpha:0.44410129709697344
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:3800, D_loss:-65.54568481445312, W_D:85.83815002441406, M_fake:54.72011184692383, M_Real:140.55825805664062, GP:0.3318939208984375, Real_P_Loss:1.9005874395370483, Fake_P_Loss:16.973529815673828, G_loss:30.501575469970703, Net_alpha:0.41321803582458305
# load 20000th file
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:4000, D_loss:-22.6318359375, W_D:35.23116683959961, M_fake:20.99968719482422, M_Real:56.23085403442383, GP:0.36920011043548584, Real_P_Loss:4.14586067199707, Fake_P_Loss:8.907329559326172, G_loss:4.367132186889648, Net_alpha:0.38233477455219267
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:4200, D_loss:-57.38438034057617, W_D:76.30734252929688, M_fake:18.46392822265625, M_Real:91.115234375, GP:0.5556925535202026, Real_P_Loss:4.829437255859375, Fake_P_Loss:13.366036415100098, G_loss:29.8304443359375, Net_alpha:0.3514515132798024
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:4400, D_loss:-115.18876647949219, W_D:130.60250854492188, M_fake:10.415409088134766, M_Real:141.01791381835938, GP:0.33649742603302, Real_P_Loss:2.9377152919769287, Fake_P_Loss:12.048770904541016, G_loss:37.840389251708984, Net_alpha:0.320568252007412
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:4600, D_loss:-92.70259857177734, W_D:107.24656677246094, M_fake:13.2371826171875, M_Real:120.48374938964844, GP:1.0895758867263794, Real_P_Loss:8.21928596496582, Fake_P_Loss:3.648211717605591, G_loss:-32.5260009765625, Net_alpha:0.28968499073502163
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:4800, D_loss:-14.104854583740234, W_D:29.50444793701172, M_fake:29.364919662475586, M_Real:101.64617156982422, GP:0.39480090141296387, Real_P_Loss:2.88787841796875, Fake_P_Loss:11.451582908630371, G_loss:-0.48613548278808594, Net_alpha:0.25880172946263125
# load 24000th file
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:5000, D_loss:-8.652896881103516, W_D:13.529008865356445, M_fake:14.823410034179688, M_Real:28.352418899536133, GP:0.07063142955303192, Real_P_Loss:1.9050369262695312, Fake_P_Loss:4.169797897338867, G_loss:9.920049667358398, Net_alpha:0.22791846819024086
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:5200, D_loss:-80.91681671142578, W_D:111.27810668945312, M_fake:72.46652221679688, M_Real:183.74462890625, GP:1.5793861150741577, Real_P_Loss:5.13078498840332, Fake_P_Loss:14.567432403564453, G_loss:-78.36610412597656, Net_alpha:0.19703520691785048
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:5400, D_loss:-77.73069763183594, W_D:82.35552978515625, M_fake:-12.071455001831055, M_Real:75.05307006835938, GP:0.12438423931598663, Real_P_Loss:2.1457955837249756, Fake_P_Loss:3.380991220474243, G_loss:33.52941131591797, Net_alpha:0.1661519456454602
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:5600, D_loss:-44.05262756347656, W_D:52.976078033447266, M_fake:-0.7211790084838867, M_Real:52.25489807128906, GP:0.42975595593452454, Real_P_Loss:3.9784011840820312, Fake_P_Loss:4.625886917114258, G_loss:42.480812072753906, Net_alpha:0.13526868437306983
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:5800, D_loss:-102.24205780029297, W_D:105.16270446777344, M_fake:58.7418327331543, M_Real:163.904541015625, GP:-0.22630275785923004, Real_P_Loss:3.281893491744995, Fake_P_Loss:5.183680057525635, G_loss:16.624805450439453, Net_alpha:0.10438542310067944
# load 25904th file
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:6000, D_loss:-69.06451416015625, W_D:80.87308502197266, M_fake:42.949485778808594, M_Real:113.77385711669922, GP:0.47655028104782104, Real_P_Loss:3.122511625289917, Fake_P_Loss:7.043066501617432, G_loss:-11.724369049072266, Net_alpha:0.07350216182828906
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:6200, D_loss:-41.4827766418457, W_D:48.7728157043457, M_fake:-4.611785888671875, M_Real:44.16102981567383, GP:0.13247093558311462, Real_P_Loss:2.381084442138672, Fake_P_Loss:5.965327739715576, G_loss:59.69029998779297, Net_alpha:0.042618900555898676
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:6400, D_loss:-41.2652473449707, W_D:50.78371810913086, M_fake:-27.551815032958984, M_Real:23.231903076171875, GP:0.24225610494613647, Real_P_Loss:1.7664337158203125, Fake_P_Loss:7.095909595489502, G_loss:54.81992721557617, Net_alpha:0.011735639283508292
# self.fadein_steps 25904 cur_step 25904 net_alpha 0.00015441630636192638
# load 4000th file
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:0, D_loss:-19.071931838989258, W_D:54.14411926269531, M_fake:25.582576751708984, M_Real:128.58526611328125, GP:1.0323362350463867, Real_P_Loss:6.2268266677856445, Fake_P_Loss:24.748825073242188, G_loss:36.68568801879883, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:200, D_loss:5.06973123550415, W_D:-0.8786087036132812, M_fake:48.91145706176758, M_Real:48.0328483581543, GP:0.13523444533348083, Real_P_Loss:2.0986063480377197, Fake_P_Loss:2.838778018951416, G_loss:110.85531616210938, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:400, D_loss:-41.9104118347168, W_D:48.448463439941406, M_fake:13.771990776062012, M_Real:62.220455169677734, GP:0.05875512957572937, Real_P_Loss:4.071210861206055, Fake_P_Loss:5.950501441955566, G_loss:13.223793029785156, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:600, D_loss:-52.31247329711914, W_D:62.53742218017578, M_fake:17.183761596679688, M_Real:97.93326568603516, GP:0.3015528917312622, Real_P_Loss:1.7173759937286377, Fake_P_Loss:7.209417343139648, G_loss:-0.01000213623046875, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:800, D_loss:12.635973930358887, W_D:-2.1223983764648438, M_fake:81.15558624267578, M_Real:79.03318786621094, GP:-0.0915709063410759, Real_P_Loss:5.261632442474365, Fake_P_Loss:11.429285049438477, G_loss:-4.7420654296875, Net_alpha:1.0
# load 8000th file
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:1000, D_loss:41.896575927734375, W_D:-33.59831237792969, M_fake:-2.2254581451416016, M_Real:-35.82377243041992, GP:0.3728819787502289, Real_P_Loss:2.8366241455078125, Fake_P_Loss:4.569441795349121, G_loss:31.07391357421875, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:1200, D_loss:-34.071746826171875, W_D:43.28081130981445, M_fake:48.4317741394043, M_Real:87.00299072265625, GP:0.3562454581260681, Real_P_Loss:3.9152770042419434, Fake_P_Loss:5.646608352661133, G_loss:-9.279003143310547, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:1400, D_loss:-35.92597579956055, W_D:36.98899459838867, M_fake:17.41579818725586, M_Real:54.40479278564453, GP:-0.10700581967830658, Real_P_Loss:3.134279251098633, Fake_P_Loss:2.1330740451812744, G_loss:8.273885726928711, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:1600, D_loss:-26.194761276245117, W_D:44.666534423828125, M_fake:57.18284606933594, M_Real:101.84938049316406, GP:0.9500410556793213, Real_P_Loss:2.713047504425049, Fake_P_Loss:8.971363067626953, G_loss:36.9745979309082, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:1800, D_loss:-27.56686019897461, W_D:31.12068748474121, M_fake:11.275164604187012, M_Real:33.05657958984375, GP:0.007065340876579285, Real_P_Loss:3.080752372741699, Fake_P_Loss:3.483172655105591, G_loss:19.532360076904297, Net_alpha:1.0
# load 12000th file
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:2000, D_loss:-42.739437103271484, W_D:47.86457824707031, M_fake:7.067039489746094, M_Real:54.931617736816406, GP:0.010546252131462097, Real_P_Loss:2.3443427085876465, Fake_P_Loss:5.019680023193359, G_loss:27.504459381103516, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:2200, D_loss:-46.762359619140625, W_D:50.69801330566406, M_fake:4.781965732574463, M_Real:55.47998046875, GP:-0.01606706529855728, Real_P_Loss:4.203961372375488, Fake_P_Loss:4.0963263511657715, G_loss:21.879283905029297, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:2400, D_loss:-9.234603881835938, W_D:23.0595703125, M_fake:31.704254150390625, M_Real:94.03211975097656, GP:0.5616244673728943, Real_P_Loss:2.1104257106781006, Fake_P_Loss:8.208722114562988, G_loss:-10.599996566772461, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:2600, D_loss:-34.35253143310547, W_D:41.909324645996094, M_fake:-8.356374740600586, M_Real:33.552947998046875, GP:0.41787245869636536, Real_P_Loss:2.499938726425171, Fake_P_Loss:3.3780651092529297, G_loss:36.06717300415039, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:2800, D_loss:-20.607999801635742, W_D:26.465885162353516, M_fake:3.7226691246032715, M_Real:30.188554763793945, GP:0.47015380859375, Real_P_Loss:3.0774028301239014, Fake_P_Loss:1.1563466787338257, G_loss:20.246871948242188, Net_alpha:1.0
# load 16000th file
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:3000, D_loss:-42.46430587768555, W_D:53.119937896728516, M_fake:-26.541259765625, M_Real:30.24781036376953, GP:0.3015407919883728, Real_P_Loss:4.43038272857666, Fake_P_Loss:7.640223503112793, G_loss:70.84508514404297, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:3200, D_loss:-26.931612014770508, W_D:37.75811004638672, M_fake:4.227456092834473, M_Real:41.985565185546875, GP:0.32205143570899963, Real_P_Loss:3.4365854263305664, Fake_P_Loss:7.605984210968018, G_loss:14.161567687988281, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:3400, D_loss:-50.29193878173828, W_D:55.89812469482422, M_fake:16.886404037475586, M_Real:72.78453063964844, GP:0.18471160531044006, Real_P_Loss:2.9388129711151123, Fake_P_Loss:3.7590718269348145, G_loss:0.9614734649658203, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:3600, D_loss:-36.3271484375, W_D:40.58513259887695, M_fake:10.029888153076172, M_Real:53.42078399658203, GP:0.26881563663482666, Real_P_Loss:3.3226733207702637, Fake_P_Loss:1.5698283910751343, G_loss:23.19684600830078, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:3800, D_loss:-35.09071350097656, W_D:35.872684478759766, M_fake:6.839114665985107, M_Real:42.71179962158203, GP:-0.24953009188175201, Real_P_Loss:2.5216495990753174, Fake_P_Loss:3.277271270751953, G_loss:30.657119750976562, Net_alpha:1.0
# load 20000th file
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:4000, D_loss:-33.73145294189453, W_D:43.89235305786133, M_fake:-9.014838218688965, M_Real:34.87751388549805, GP:0.6113084554672241, Real_P_Loss:3.4112935066223145, Fake_P_Loss:4.047811985015869, G_loss:31.120529174804688, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:4200, D_loss:-9.58491325378418, W_D:16.672340393066406, M_fake:26.23129653930664, M_Real:88.31236267089844, GP:-0.15335828065872192, Real_P_Loss:2.207550048828125, Fake_P_Loss:8.621009826660156, G_loss:-4.155796051025391, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:4400, D_loss:33.37905502319336, W_D:-22.204166412353516, M_fake:-23.603214263916016, M_Real:-45.80738067626953, GP:0.5283817052841187, Real_P_Loss:3.1907994747161865, Fake_P_Loss:5.891070365905762, G_loss:93.79238891601562, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:4600, D_loss:-5.438913345336914, W_D:22.406715393066406, M_fake:57.658538818359375, M_Real:80.06525421142578, GP:0.8150058388710022, Real_P_Loss:3.0385236740112305, Fake_P_Loss:8.817743301391602, G_loss:24.856456756591797, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:4800, D_loss:-13.405677795410156, W_D:22.46910285949707, M_fake:-11.385639190673828, M_Real:-6.043369293212891, GP:0.26878514885902405, Real_P_Loss:2.657367467880249, Fake_P_Loss:6.375574111938477, G_loss:37.959312438964844, Net_alpha:1.0
# load 24000th file
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:5000, D_loss:25.25519371032715, W_D:-24.41881561279297, M_fake:-9.049320220947266, M_Real:-33.468135833740234, GP:-0.049418121576309204, Real_P_Loss:2.837327480316162, Fake_P_Loss:1.330559492111206, G_loss:42.77577209472656, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:5200, D_loss:-39.21527862548828, W_D:37.791900634765625, M_fake:-55.156227111816406, M_Real:-17.36432647705078, GP:-0.28402215242385864, Real_P_Loss:6.134403705596924, Fake_P_Loss:1.416844367980957, G_loss:83.34347534179688, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:5400, D_loss:-17.748075485229492, W_D:52.22642517089844, M_fake:103.35391998291016, M_Real:220.73165893554688, GP:0.7480524182319641, Real_P_Loss:3.395066261291504, Fake_P_Loss:26.997825622558594, G_loss:-69.40325927734375, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:5600, D_loss:-90.80717468261719, W_D:104.05659484863281, M_fake:51.0097541809082, M_Real:155.06634521484375, GP:0.17913490533828735, Real_P_Loss:3.1203742027282715, Fake_P_Loss:11.458070755004883, G_loss:4.056297302246094, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:5800, D_loss:-33.425689697265625, W_D:35.21650695800781, M_fake:-14.020822525024414, M_Real:21.1956844329834, GP:-0.12345675379037857, Real_P_Loss:3.0483717918395996, Fake_P_Loss:3.0253818035125732, G_loss:41.09514236450195, Net_alpha:1.0
# load 25904th file
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:6000, D_loss:-79.78199768066406, W_D:87.33209228515625, M_fake:-31.027122497558594, M_Real:47.722713470458984, GP:0.06590652465820312, Real_P_Loss:5.2304182052612305, Fake_P_Loss:6.891028881072998, G_loss:83.33130645751953, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:6200, D_loss:-30.626367568969727, W_D:38.594364166259766, M_fake:-39.68467712402344, M_Real:-1.0903139114379883, GP:0.08446062356233597, Real_P_Loss:4.3779377937316895, Fake_P_Loss:7.123389720916748, G_loss:-16.825416564941406, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:6400, D_loss:-26.797439575195312, W_D:3.1119232177734375, M_fake:110.33853149414062, M_Real:113.45045471191406, GP:-3.3251922130584717, Real_P_Loss:5.055117607116699, Fake_P_Loss:9.566405296325684, G_loss:12.390922546386719, Net_alpha:1.0
# self.fadein_steps 25904 cur_step 25904 net_alpha 1.0
# load 4000th file
# Resolution:32x1024, Status:stable, Cur_step:1, Batch_id:0, D_loss:42.94047546386719, W_D:-25.348960876464844, M_fake:-50.06858825683594, M_Real:40.866371154785156, GP:0.2599267363548279, Real_P_Loss:3.5355842113494873, Fake_P_Loss:14.992250442504883, G_loss:85.42443084716797, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:1, Batch_id:200, D_loss:-109.56596374511719, W_D:117.63555145263672, M_fake:48.858619689941406, M_Real:166.49417114257812, GP:-0.14449071884155273, Real_P_Loss:3.546971559524536, Fake_P_Loss:9.514492988586426, G_loss:-2.835784912109375, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:1, Batch_id:400, D_loss:-37.709537506103516, W_D:42.89952087402344, M_fake:-2.9788875579833984, M_Real:39.92063522338867, GP:0.07450554519891739, Real_P_Loss:3.1926651000976562, Fake_P_Loss:4.4449262619018555, G_loss:1.153223991394043, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:1, Batch_id:600, D_loss:-83.0528793334961, W_D:95.72610473632812, M_fake:45.83100891113281, M_Real:132.8850860595703, GP:0.056562379002571106, Real_P_Loss:4.730580806732178, Fake_P_Loss:12.107605934143066, G_loss:1.4748001098632812, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:1, Batch_id:800, D_loss:-70.637451171875, W_D:74.10543823242188, M_fake:-5.450923919677734, M_Real:68.6545181274414, GP:0.060760945081710815, Real_P_Loss:4.878406524658203, Fake_P_Loss:2.8603708744049072, G_loss:27.597745895385742, Net_alpha:1.0
# load 8000th file
# Resolution:32x1024, Status:stable, Cur_step:1, Batch_id:1000, D_loss:-68.36962890625, W_D:77.63965606689453, M_fake:-11.246453285217285, M_Real:66.39320373535156, GP:0.5572519302368164, Real_P_Loss:4.080033302307129, Fake_P_Loss:3.697511911392212, G_loss:46.2942008972168, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:1, Batch_id:1200, D_loss:-45.66402053833008, W_D:58.06845474243164, M_fake:37.75157165527344, M_Real:99.37250518798828, GP:0.06620104610919952, Real_P_Loss:6.014001846313477, Fake_P_Loss:11.742424964904785, G_loss:22.388446807861328, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:1, Batch_id:1400, D_loss:-27.826622009277344, W_D:30.267131805419922, M_fake:57.123958587646484, M_Real:87.3910903930664, GP:-0.18788877129554749, Real_P_Loss:2.3099205493927, Fake_P_Loss:4.319396495819092, G_loss:-46.18055725097656, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:1, Batch_id:1600, D_loss:-38.36396408081055, W_D:52.58259582519531, M_fake:11.210478782653809, M_Real:63.79307556152344, GP:0.7317150235176086, Real_P_Loss:2.8299059867858887, Fake_P_Loss:6.901483535766602, G_loss:27.82694435119629, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:1, Batch_id:1800, D_loss:-107.94134521484375, W_D:131.59739685058594, M_fake:75.77367401123047, M_Real:207.9847869873047, GP:-0.1270083338022232, Real_P_Loss:4.220751762390137, Fake_P_Loss:24.926132202148438, G_loss:-33.56615447998047, Net_alpha:1.0
# load 12000th file
# Resolution:32x1024, Status:stable, Cur_step:1, Batch_id:2000, D_loss:-36.16394805908203, W_D:44.61016845703125, M_fake:-36.477317810058594, M_Real:8.132852554321289, GP:0.20612049102783203, Real_P_Loss:7.229724884033203, Fake_P_Loss:6.385016441345215, G_loss:63.919795989990234, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:1, Batch_id:2200, D_loss:-86.47035217285156, W_D:40.326560974121094, M_fake:32.455291748046875, M_Real:72.78185272216797, GP:-5.29379940032959, Real_P_Loss:4.131773948669434, Fake_P_Loss:6.7942023277282715, G_loss:-20.413307189941406, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:1, Batch_id:2400, D_loss:-19.87201690673828, W_D:32.656986236572266, M_fake:6.19188117980957, M_Real:54.80068588256836, GP:0.9736239314079285, Real_P_Loss:1.4564547538757324, Fake_P_Loss:3.0487303733825684, G_loss:8.372666358947754, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:1, Batch_id:2600, D_loss:-7.661473274230957, W_D:17.922698974609375, M_fake:47.03374481201172, M_Real:64.9564437866211, GP:0.41961491107940674, Real_P_Loss:2.1417417526245117, Fake_P_Loss:6.065077304840088, G_loss:-10.911075592041016, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:1, Batch_id:2800, D_loss:-29.86472511291504, W_D:40.3630485534668, M_fake:15.903964042663574, M_Real:56.26701354980469, GP:0.4920896887779236, Real_P_Loss:2.314253330230713, Fake_P_Loss:5.577427864074707, G_loss:25.059341430664062, Net_alpha:1.0
# load 16000th file
# ...
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:4200, D_loss:-0.9757740497589111, W_D:0.7858543395996094, M_fake:28.338886260986328, M_Real:33.31355285644531, GP:-0.23170284926891327, Real_P_Loss:2.352849006652832, Fake_P_Loss:2.1271088123321533, G_loss:-4.810396194458008, Net_alpha:0.3514515132798024
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:4400, D_loss:-33.03010559082031, W_D:42.152076721191406, M_fake:21.946006774902344, M_Real:64.09808349609375, GP:0.3525061011314392, Real_P_Loss:4.1188554763793945, Fake_P_Loss:5.5969085693359375, G_loss:10.721939086914062, Net_alpha:0.320568252007412
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:4600, D_loss:-43.10002136230469, W_D:50.7427864074707, M_fake:0.5113134384155273, M_Real:51.25410079956055, GP:0.5901094675064087, Real_P_Loss:6.484184265136719, Fake_P_Loss:1.7416670322418213, G_loss:17.608787536621094, Net_alpha:0.28968499073502163
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:4800, D_loss:-23.106143951416016, W_D:34.5770149230957, M_fake:36.772430419921875, M_Real:80.15449523925781, GP:0.18714579939842224, Real_P_Loss:4.6454691886901855, Fake_P_Loss:9.59941291809082, G_loss:9.682262420654297, Net_alpha:0.25880172946263125
# load 24000th file
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:5000, D_loss:-2.7299251556396484, W_D:2.9636707305908203, M_fake:18.77345085144043, M_Real:21.73712158203125, GP:-0.12939085066318512, Real_P_Loss:4.054969787597656, Fake_P_Loss:1.5276541709899902, G_loss:-18.8061466217041, Net_alpha:0.22791846819024086
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:5200, D_loss:-63.7767333984375, W_D:82.1058578491211, M_fake:15.157221794128418, M_Real:97.26307678222656, GP:0.30470967292785645, Real_P_Loss:5.415571212768555, Fake_P_Loss:15.282025337219238, G_loss:124.008544921875, Net_alpha:0.19703520691785048
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:5400, D_loss:17.686935424804688, W_D:-8.049560546875, M_fake:123.25318908691406, M_Real:161.8182373046875, GP:-0.19480670988559723, Real_P_Loss:2.966972827911377, Fake_P_Loss:11.585440635681152, G_loss:-93.58346557617188, Net_alpha:0.1661519456454602
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:5600, D_loss:-66.59857940673828, W_D:89.91073608398438, M_fake:87.76495361328125, M_Real:177.67568969726562, GP:0.261788010597229, Real_P_Loss:6.174509525299072, Fake_P_Loss:20.694276809692383, G_loss:-141.32720947265625, Net_alpha:0.13526868437306983
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:5800, D_loss:-73.03966522216797, W_D:130.61111450195312, M_fake:111.4150390625, M_Real:242.02615356445312, GP:0.41050979495048523, Real_P_Loss:7.0360026359558105, Fake_P_Loss:53.46635437011719, G_loss:101.99642944335938, Net_alpha:0.10438542310067944
# load 25904th file
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:6000, D_loss:-75.65327453613281, W_D:87.44034576416016, M_fake:63.222328186035156, M_Real:140.38619995117188, GP:0.6913316249847412, Real_P_Loss:4.392248153686523, Fake_P_Loss:4.8737568855285645, G_loss:-19.299846649169922, Net_alpha:0.07350216182828906
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:6200, D_loss:-112.76734161376953, W_D:131.98446655273438, M_fake:-38.38070297241211, M_Real:93.60376739501953, GP:0.2291005253791809, Real_P_Loss:11.240507125854492, Fake_P_Loss:16.92612075805664, G_loss:-64.40325164794922, Net_alpha:0.042618900555898676
# Resolution:32x1024, Status:fadein, Cur_step:0, Batch_id:6400, D_loss:-60.886348724365234, W_D:81.89778137207031, M_fake:58.02970504760742, M_Real:139.927490234375, GP:0.02285829186439514, Real_P_Loss:5.8326029777526855, Fake_P_Loss:20.782848358154297, G_loss:-120.56050109863281, Net_alpha:0.011735639283508292
# self.fadein_steps 25904 cur_step 25904 net_alpha 0.00015441630636192638
# load 4000th file
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:0, D_loss:-14.269457817077637, W_D:30.82232093811035, M_fake:-40.130706787109375, M_Real:57.93150329589844, GP:0.32576414942741394, Real_P_Loss:8.924942016601562, Fake_P_Loss:13.295221328735352, G_loss:129.380126953125, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:200, D_loss:9.566556930541992, W_D:-5.997142791748047, M_fake:44.830142974853516, M_Real:38.83300018310547, GP:0.16156059503555298, Real_P_Loss:1.7068190574645996, Fake_P_Loss:1.9538078308105469, G_loss:50.85587692260742, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:400, D_loss:-63.31656265258789, W_D:82.98104858398438, M_fake:-9.668195724487305, M_Real:73.31285095214844, GP:0.7401020526885986, Real_P_Loss:5.982047080993652, Fake_P_Loss:12.263465881347656, G_loss:22.105649948120117, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:600, D_loss:-23.52998161315918, W_D:31.990478515625, M_fake:35.432960510253906, M_Real:71.31094360351562, GP:-0.3052656352519989, Real_P_Loss:3.4402151107788086, Fake_P_Loss:11.513153076171875, G_loss:-1.0308074951171875, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:800, D_loss:-67.39875793457031, W_D:77.93817901611328, M_fake:14.720198631286621, M_Real:92.65837860107422, GP:0.17933422327041626, Real_P_Loss:5.723206043243408, Fake_P_Loss:8.746076583862305, G_loss:34.458736419677734, Net_alpha:1.0
# load 8000th file
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:1000, D_loss:34.833980560302734, W_D:-26.23267364501953, M_fake:63.229217529296875, M_Real:36.996543884277344, GP:0.19210538268089294, Real_P_Loss:1.8503925800323486, Fake_P_Loss:6.680251121520996, G_loss:45.47696304321289, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:1200, D_loss:-46.20055389404297, W_D:49.838134765625, M_fake:15.824322700500488, M_Real:66.58575439453125, GP:0.24102383852005005, Real_P_Loss:6.721433639526367, Fake_P_Loss:1.227340579032898, G_loss:51.390018463134766, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:1400, D_loss:-28.690052032470703, W_D:37.14358901977539, M_fake:21.038105010986328, M_Real:58.18169403076172, GP:0.47474297881126404, Real_P_Loss:4.557636260986328, Fake_P_Loss:3.706108331680298, G_loss:27.234769821166992, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:1600, D_loss:-74.90392303466797, W_D:91.03077697753906, M_fake:25.523868560791016, M_Real:116.55464172363281, GP:0.16678880155086517, Real_P_Loss:7.115671157836914, Fake_P_Loss:14.458970069885254, G_loss:47.92452621459961, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:1800, D_loss:-48.432369232177734, W_D:54.95364761352539, M_fake:51.60790252685547, M_Real:102.62763977050781, GP:0.007552787661552429, Real_P_Loss:4.604226112365723, Fake_P_Loss:6.4457502365112305, G_loss:-5.565643310546875, Net_alpha:1.0
# load 12000th file
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:2000, D_loss:-24.769315719604492, W_D:28.085689544677734, M_fake:35.6908073425293, M_Real:63.77649688720703, GP:-0.10419107228517532, Real_P_Loss:8.281062126159668, Fake_P_Loss:4.358284950256348, G_loss:17.44982147216797, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:2200, D_loss:-33.45496368408203, W_D:25.719970703125, M_fake:20.575157165527344, M_Real:46.295127868652344, GP:-0.8769617676734924, Real_P_Loss:3.2472939491271973, Fake_P_Loss:1.034623384475708, G_loss:-22.365581512451172, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:2400, D_loss:-39.31334686279297, W_D:43.01158905029297, M_fake:44.92621612548828, M_Real:79.05181121826172, GP:-0.04221820831298828, Real_P_Loss:3.2487289905548096, Fake_P_Loss:4.120420932769775, G_loss:-12.438926696777344, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:2600, D_loss:-7.632904052734375, W_D:15.265689849853516, M_fake:19.909751892089844, M_Real:35.17544174194336, GP:0.4949133098125458, Real_P_Loss:3.2875828742980957, Fake_P_Loss:2.683652400970459, G_loss:21.33647346496582, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:2800, D_loss:-56.022701263427734, W_D:71.57914733886719, M_fake:2.5414276123046875, M_Real:74.12057495117188, GP:0.27745679020881653, Real_P_Loss:6.425781726837158, Fake_P_Loss:12.781879425048828, G_loss:46.699440002441406, Net_alpha:1.0
# load 16000th file
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:3000, D_loss:-45.42573547363281, W_D:49.54207992553711, M_fake:19.22827911376953, M_Real:58.89032745361328, GP:0.0665874257683754, Real_P_Loss:9.479276657104492, Fake_P_Loss:3.4504690170288086, G_loss:75.56449127197266, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:3200, D_loss:-25.13709259033203, W_D:41.29240798950195, M_fake:32.97487258911133, M_Real:74.26728057861328, GP:0.524986743927002, Real_P_Loss:6.41287899017334, Fake_P_Loss:10.905448913574219, G_loss:-6.894618988037109, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:3400, D_loss:-1.879232406616211, W_D:10.999401092529297, M_fake:31.53899383544922, M_Real:42.538394927978516, GP:-0.050396353006362915, Real_P_Loss:6.239549160003662, Fake_P_Loss:9.62413215637207, G_loss:-25.658279418945312, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:3600, D_loss:-12.550750732421875, W_D:19.448217391967773, M_fake:7.600963592529297, M_Real:47.05815505981445, GP:0.385680228471756, Real_P_Loss:4.429416656494141, Fake_P_Loss:3.0406653881073, G_loss:36.69320297241211, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:3800, D_loss:-20.655895233154297, W_D:35.72092056274414, M_fake:25.10147476196289, M_Real:60.82239532470703, GP:0.7643078565597534, Real_P_Loss:5.598190784454346, Fake_P_Loss:7.421947479248047, G_loss:-49.70246124267578, Net_alpha:1.0
# load 20000th file
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:4000, D_loss:-1.049295425415039, W_D:20.02774429321289, M_fake:47.36019515991211, M_Real:67.387939453125, GP:0.884053647518158, Real_P_Loss:4.520171165466309, Fake_P_Loss:10.13791275024414, G_loss:48.62577819824219, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:4200, D_loss:-4.683428764343262, W_D:10.153915405273438, M_fake:26.52639389038086, M_Real:44.06712341308594, GP:0.19897106289863586, Real_P_Loss:2.7957091331481934, Fake_P_Loss:3.4807755947113037, G_loss:1.4306983947753906, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:4400, D_loss:-33.09600067138672, W_D:33.19091796875, M_fake:5.608055114746094, M_Real:38.798973083496094, GP:-0.11967064440250397, Real_P_Loss:6.624321460723877, Fake_P_Loss:1.291621208190918, G_loss:-2.8085899353027344, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:4600, D_loss:-13.715704917907715, W_D:19.811012268066406, M_fake:49.729393005371094, M_Real:69.5404052734375, GP:0.30541467666625977, Real_P_Loss:2.211744546890259, Fake_P_Loss:3.0411605834960938, G_loss:15.068115234375, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:4800, D_loss:-0.7896151542663574, W_D:5.358541488647461, M_fake:6.110607624053955, M_Real:15.689022064208984, GP:0.425477534532547, Real_P_Loss:1.7988066673278809, Fake_P_Loss:0.3141508102416992, G_loss:11.877460479736328, Net_alpha:1.0
# load 24000th file
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:5000, D_loss:-7.740479946136475, W_D:10.503640174865723, M_fake:13.859034538269043, M_Real:24.362674713134766, GP:0.10632099211215973, Real_P_Loss:4.7256317138671875, Fake_P_Loss:1.6999506950378418, G_loss:26.827014923095703, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:5200, D_loss:-93.84391784667969, W_D:102.84365844726562, M_fake:3.470290184020996, M_Real:106.31394958496094, GP:-0.46400630474090576, Real_P_Loss:9.614081382751465, Fake_P_Loss:13.63979721069336, G_loss:-70.8111572265625, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:5400, D_loss:-56.19173812866211, W_D:77.64447021484375, M_fake:41.81431579589844, M_Real:107.94540405273438, GP:0.6442699432373047, Real_P_Loss:5.906946182250977, Fake_P_Loss:15.010031700134277, G_loss:17.255146026611328, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:5600, D_loss:-46.24358367919922, W_D:62.29283142089844, M_fake:33.11608123779297, M_Real:95.4089126586914, GP:0.4057823419570923, Real_P_Loss:6.4352006912231445, Fake_P_Loss:11.991426467895508, G_loss:-87.28031921386719, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:5800, D_loss:-93.93830108642578, W_D:114.25233459472656, M_fake:-41.4920768737793, M_Real:72.76026153564453, GP:0.4769597053527832, Real_P_Loss:21.15892219543457, Fake_P_Loss:15.544434547424316, G_loss:105.15479278564453, Net_alpha:1.0
# load 25904th file
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:6000, D_loss:-61.67462158203125, W_D:64.80267333984375, M_fake:67.22972106933594, M_Real:121.32296752929688, GP:-1.000000260376055e-08, Real_P_Loss:7.568401336669922, Fake_P_Loss:3.1280529499053955, G_loss:8.454292297363281, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:6200, D_loss:-43.80101013183594, W_D:56.98689651489258, M_fake:5.5053911209106445, M_Real:62.492286682128906, GP:0.20621035993099213, Real_P_Loss:6.418690204620361, Fake_P_Loss:11.12378215789795, G_loss:46.499542236328125, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:0, Batch_id:6400, D_loss:-2.7190752029418945, W_D:4.231498718261719, M_fake:96.18959045410156, M_Real:100.42108917236328, GP:-0.27012285590171814, Real_P_Loss:2.755034923553467, Fake_P_Loss:4.21365213394165, G_loss:14.407291412353516, Net_alpha:1.0
# self.fadein_steps 25904 cur_step 25904 net_alpha 1.0
# load 4000th file
# Resolution:32x1024, Status:stable, Cur_step:1, Batch_id:0, D_loss:-28.48797035217285, W_D:44.16317367553711, M_fake:7.39813232421875, M_Real:63.628326416015625, GP:0.764773428440094, Real_P_Loss:10.489616394042969, Fake_P_Loss:8.02746868133545, G_loss:97.49803161621094, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:1, Batch_id:200, D_loss:0.13115501403808594, W_D:7.500465393066406, M_fake:70.83631134033203, M_Real:78.33677673339844, GP:0.22531403601169586, Real_P_Loss:2.2571020126342773, Fake_P_Loss:5.378479957580566, G_loss:13.402156829833984, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:1, Batch_id:400, D_loss:-40.51839065551758, W_D:43.987876892089844, M_fake:-14.851511001586914, M_Real:29.13636589050293, GP:0.3354150056838989, Real_P_Loss:6.90468168258667, Fake_P_Loss:0.11533762514591217, G_loss:19.390239715576172, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:1, Batch_id:600, D_loss:-12.04916763305664, W_D:10.550922393798828, M_fake:31.733287811279297, M_Real:46.30266571044922, GP:-0.3084982633590698, Real_P_Loss:2.633296251296997, Fake_P_Loss:1.5867376327514648, G_loss:-5.400325775146484, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:1, Batch_id:800, D_loss:-3.585120439529419, W_D:10.712825775146484, M_fake:55.74801254272461, M_Real:66.4608383178711, GP:0.3917757272720337, Real_P_Loss:2.199366569519043, Fake_P_Loss:3.2099480628967285, G_loss:50.82026290893555, Net_alpha:1.0
# load 8000th file
# Resolution:32x1024, Status:stable, Cur_step:1, Batch_id:1000, D_loss:38.26103973388672, W_D:-31.81993865966797, M_fake:84.13606262207031, M_Real:52.316123962402344, GP:0.028280198574066162, Real_P_Loss:2.5084714889526367, Fake_P_Loss:6.158298969268799, G_loss:9.260444641113281, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:1, Batch_id:1200, D_loss:-40.07795333862305, W_D:58.31549072265625, M_fake:18.502975463867188, M_Real:71.83126068115234, GP:0.7032199501991272, Real_P_Loss:6.927208423614502, Fake_P_Loss:11.205338478088379, G_loss:50.76911163330078, Net_alpha:1.0
# Resolution:32x1024, Status:stable, Cur_step:1, Batch_id:1400, D_loss:-26.601985931396484, W_D:26.058013916015625, M_fake:37.80740737915039, M_Real:63.865421295166016, GP:-0.5169236063957214, Real_P_Loss:5.057535171508789, Fake_P_Loss:4.625265121459961, G_loss:16.13189697265625, Net_alpha:1.0
